# %%
import pandas as pd
from datetime import datetime

# %%
def connectCollectedData(BCI_filename, labels_filename):
    # reads in te data from txt files
    with open("gui_data/" + labels_filename) as f:
        labels_content = f.readlines()

    data = pd.read_csv('Open BCI Saved Data/' + BCI_filename, skiprows=6, sep=" ", header=None)
    data = data.drop(columns=[0, 17, 18, 19])
    
    # Now we start adding labels
    # If we record our data at midnight then the code probably won't work
    # label values 0 stands for none
    # label value 1 stands for right hand
    # label value 2 stands for left hand
    # label value 5 stands for the period when our program was not working

    label_row = labels_content[0].strip().split("\t")  # taking the row where we started program
    label_time = datetime.strptime(label_row[0], '%Y-%m-%d %H:%M:%S.%f').time()
    label_value = 5    # I assume that the data recording started before the program

    new_label_index = 1        # here I set the next row_nr row index for labels data
    labels = []

    for index, row in data.iterrows():
        row_time = datetime.strptime(row[20], '%H:%M:%S.%f').time()
        if row_time >= label_time:                                                # time to change the label
            if new_label_index >= len(labels_content):                     # no more information in file
                label_value = 5
                label_time = datetime.strptime("23:59:59.9999", '%H:%M:%S.%f').time()
            else:
                label_value = getNewLabel(label_row[1])
                label_row = labels_content[new_label_index].strip().split("\t")
                new_label_index += 1
                label_time = datetime.strptime(label_row[0], '%Y-%m-%d %H:%M:%S.%f').time()
        labels.append(label_value)

    data['label'] = pd.Series(labels, index=data.index)
    return data
    
    
def getNewLabel(message):
    if message == "end" or message == "start":
        return 0
    if "right" in message:
        return 1
    if "left" in message:
        return 2
    print("problem with the following message:")
    print(message)

# %%
connectCollectedData("OpenBCI-RAW-2018-04-20_11-51-33.txt","connections_test.txt")
# Out:
#                  1            2            3            4            5  \
# 0      -149712.94,  -187500.02,  -124192.30,  -114609.48,  -187500.02,
# 1      -149818.44,  -187500.02,  -124183.92,  -114594.15,  -187500.02,
# 2      -149455.78,  -187500.02,  -124088.09,  -114601.32,  -187500.02,
# 3      -149829.91,  -187500.02,  -124203.50,  -114575.71,  -187500.02,
# 4      -149481.56,  -187500.02,  -124064.07,  -114579.69,  -187500.02,
# 5      -149574.34,  -187500.02,  -124129.83,  -114571.82,  -187500.02,
# 6      -149687.75,  -187500.02,  -124123.52,  -114557.07,  -187500.02,
# 7      -149334.09,  -187500.02,  -124026.85,  -114562.81,  -187500.02,
# 8      -149723.88,  -187500.02,  -124149.27,  -114542.67,  -187500.02,
# 9      -149386.97,  -187500.02,  -124010.89,  -114547.10,  -187500.02,
# 10     -149489.48,  -187500.02,  -124079.02,  -114541.45,  -187500.02,
# 11     -149608.22,  -187500.02,  -124071.63,  -114524.70,  -187500.02,
# 12     -149266.23,  -187500.02,  -123982.28,  -114537.20,  -187500.02,
# 13     -149664.69,  -187500.02,  -124108.70,  -114518.84,  -187500.02,
# 14     -149334.39,  -187500.02,  -123969.77,  -114520.66,  -187500.02,
# 15     -149443.33,  -187500.02,  -124037.09,  -114511.73,  -187500.02,
# 16     -149584.08,  -187500.02,  -124039.99,  -114500.83,  -187500.02,
# 17     -149256.61,  -187500.02,  -123953.67,  -114513.39,  -187500.02,
# 18     -149664.92,  -187500.02,  -124080.41,  -114491.29,  -187500.02,
# 34106    -6976.87,   -20669.73,    -7103.47,   -16657.62,  -156565.58,
# 34107    -7221.29,   -20875.39,    -7169.39,   -16660.56,  -156589.45,
# 34108    -7213.98,   -20857.02,    -7142.12,   -16643.44,  -156597.19,
#
#                  6            7            8            9           10  \
# 0      -172319.22,  -187500.02,  -187500.02,  -128615.20,  -124700.96,
# 1      -172330.41,  -187500.02,  -187500.02,  -128275.95,  -124591.97,
# 2      -172437.00,  -187500.02,  -187500.02,  -128353.26,  -124582.20,
# 3      -172263.53,  -187500.02,  -187500.02,  -128466.91,  -124626.66,
# 4      -172447.70,  -187500.02,  -187500.02,  -128111.84,  -124502.66,
# 5      -172337.58,  -187500.02,  -187500.02,  -128490.30,  -124620.36,
# 6      -172349.64,  -187500.02,  -187500.02,  -128160.96,  -124531.48,
# 7      -172455.75,  -187500.02,  -187500.02,  -128249.68,  -124540.23,
# 8      -172285.66,  -187500.02,  -187500.02,  -128379.12,  -124597.02,
# 9      -172468.69,  -187500.02,  -187500.02,  -128034.43,  -124474.13,
# 10     -172357.94,  -187500.02,  -187500.02,  -128419.30,  -124581.78,
# 11     -172363.02,  -187500.02,  -187500.02,  -128102.09,  -124488.46,
# 12     -172472.45,  -187500.02,  -187500.02,  -128200.08,  -124494.27,
# 13     -172300.42,  -187500.02,  -187500.02,  -128337.41,  -124551.45,
# 14     -172477.98,  -187500.02,  -187500.02,  -127996.81,  -124432.73,
# 15     -172361.34,  -187500.02,  -187500.02,  -128395.50,  -124558.02,
# 16     -172368.27,  -187500.02,  -187500.02,  -128095.45,  -124485.04,
# 17     -172475.05,  -187500.02,  -187500.02,  -128204.46,  -124504.11,
# 18     -172293.98,  -187500.02,  -187500.02,  -128352.56,  -124567.83,
# 19     -172472.00,  -187500.02,  -187500.02,  -128025.94,  -124457.52,
# 20     -172356.84,  -187500.02,  -187500.02,  -128426.19,  -124576.57,
# 21     -172357.16,  -187500.02,  -187500.02,  -128121.13,  -124492.04,
# 22     -172461.42,  -187500.02,  -187500.02,  -128221.88,  -124501.63,
# 23     -172283.31,  -187500.02,  -187500.02,  -128365.08,  -124561.48,
# 24     -172458.59,  -187500.02,  -187500.02,  -128027.86,  -124446.88,
# 25     -172347.13,  -187500.02,  -187500.02,  -128420.36,  -124566.85,
# 26     -172350.14,  -187500.02,  -187500.02,  -128105.84,  -124480.30,
# 27     -172456.13,  -187500.02,  -187500.02,  -128196.55,  -124487.23,
# 28     -172278.03,  -187500.02,  -187500.02,  -128333.63,  -124542.02,
# 29     -172453.81,  -187500.02,  -187500.02,  -127991.07,  -124420.67,
# ...            ...          ...          ...          ...          ...
# 34079  -181919.59,  -187500.02,  -187500.02,    -6824.17,    -9498.89,
# 34080  -181867.00,  -187500.02,  -187500.02,    -7180.61,    -9696.70,
# 34081  -181898.61,  -187500.02,  -187500.02,    -6806.20,    -9482.41,
# 34082  -181892.52,  -187500.02,  -187500.02,    -7053.61,    -9607.29,
# 34083  -181866.91,  -187500.02,  -187500.02,    -6950.77,    -9549.92,
# 34084  -181889.06,  -187500.02,  -187500.02,    -7049.78,    -9586.71,
# 34085  -181861.13,  -187500.02,  -187500.02,    -7028.39,    -9577.79,
# 34086  -181906.92,  -187500.02,  -187500.02,    -6818.42,    -9437.55,
# 34087  -181854.45,  -187500.02,  -187500.02,    -7173.93,    -9628.13,
# 34088  -181886.16,  -187500.02,  -187500.02,    -6803.74,    -9410.87,
# 34089  -181880.09,  -187500.02,  -187500.02,    -7043.57,    -9523.94,
# 34090  -181851.95,  -187500.02,  -187500.02,    -7023.10,    -9515.00,
# 34091  -181898.33,  -187500.02,  -187500.02,    -6813.42,    -9378.77,
# 34092  -181847.80,  -187500.02,  -187500.02,    -7172.90,    -9576.65,
# 34093  -181880.11,  -187500.02,  -187500.02,    -6800.79,    -9362.05,
# 34094  -181872.70,  -187500.02,  -187500.02,    -7040.73,    -9478.99,
# 34095  -181846.75,  -187500.02,  -187500.02,    -7026.18,    -9475.33,
# 34096  -181894.47,  -187500.02,  -187500.02,    -6811.58,    -9335.74,
# 34097  -181842.91,  -187500.02,  -187500.02,    -7171.87,    -9534.23,
# 34098  -181875.11,  -187500.02,  -187500.02,    -6800.23,    -9320.23,
# 34099  -181870.14,  -187500.02,  -187500.02,    -7037.80,    -9436.77,
# 34100  -181843.80,  -187500.02,  -187500.02,    -7023.66,    -9432.91,
# 34101  -181887.47,  -187500.02,  -187500.02,    -6804.00,    -9290.32,
# 34102  -181834.98,  -187500.02,  -187500.02,    -7164.90,    -9490.71,
# 34103  -181866.55,  -187500.02,  -187500.02,    -6795.96,    -9281.09,
# 34104  -181861.00,  -187500.02,  -187500.02,    -7029.91,    -9396.83,
# 34105  -181834.75,  -187500.02,  -187500.02,    -7022.25,    -9398.57,
# 34106  -181880.59,  -187500.02,  -187500.02,    -6800.67,    -9254.14,
# 34107  -181828.58,  -187500.02,  -187500.02,    -7164.96,    -9453.27,
# 34108  -181861.20,  -187500.02,  -187500.02,    -6795.53,    -9237.39,
#
#                 11           12           13           14           15  \
# 0      -119545.93,  -116498.47,  -184221.50,  -180580.98,  -163441.05,
# 1      -119394.92,  -116449.16,  -183988.64,  -180623.25,  -163394.16,
# 2      -119449.53,  -116464.68,  -184058.66,  -180574.94,  -163423.56,
# 3      -119458.31,  -116454.17,  -184120.55,  -180595.36,  -163405.44,
# 4      -119340.45,  -116422.16,  -183897.39,  -180599.19,  -163391.66,
# 5      -119480.76,  -116453.75,  -184152.03,  -180566.84,  -163424.11,
# 6      -119332.67,  -116402.47,  -183924.98,  -180611.97,  -163376.88,
# 7      -119392.04,  -116419.13,  -184002.73,  -180567.83,  -163408.17,
# 8      -119407.73,  -116413.34,  -184076.52,  -180594.47,  -163393.73,
# 9      -119291.73,  -116383.85,  -183860.44,  -180601.94,  -163379.05,
# 10     -119431.65,  -116416.58,  -184118.48,  -180568.00,  -163409.13,
# 11     -119288.93,  -116372.34,  -183900.00,  -180617.38,  -163365.50,
# 12     -119352.90,  -116395.52,  -183984.53,  -180577.19,  -163399.98,
# 13     -119370.27,  -116390.60,  -184062.47,  -180602.47,  -163384.89,
